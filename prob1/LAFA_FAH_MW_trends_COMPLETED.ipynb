# %% [markdown]
# # LAFA Food-At-Home Trends for Men and Women (1994–1998 to 2007–2008)
#
# Using `pandas.read_excel` (no external reformatting), we load FAH sheets, pull **Men/Women mean shares (%)** for selected fruit and dairy items, and produce four line plots with labeled axes, distinct linestyles, legends, and source text.

# %%
sheet_map
# Out:
# {
#   "1994-1998": "94-98 FAH",
#   "2003-2004": "03-04 FAH",
#   "2005-2006": "05-06 FAH",
#   "2007-2008": "07-08 FAH"
# }

# %%
tidy.head(20)
# Out:
#        period             product gender   mean  group
# 0   1994-1998     Apples as fruit    Men  89.18  Fruit
# 1   1994-1998     Apples as fruit  Women  90.42  Fruit
# 2   1994-1998             Bananas    Men  95.42  Fruit
# 3   1994-1998             Bananas  Women  94.18  Fruit
# 4   1994-1998             Berries    Men  84.21  Fruit
# 5   1994-1998             Berries  Women  81.73  Fruit
# 6   1994-1998              Grapes    Men  88.79  Fruit
# 7   1994-1998              Grapes  Women  88.13  Fruit
# 8   1994-1998              Melons    Men  80.74  Fruit
# 9   1994-1998              Melons  Women  84.96  Fruit
# 10  1994-1998      Oranges, Total    Men  85.66  Fruit
# 11  1994-1998      Oranges, Total  Women  89.77  Fruit
# 12  1994-1998  Other citrus fruit    Men  79.82  Fruit
# 13  1994-1998  Other citrus fruit  Women  80.64  Fruit
# 14  1994-1998         Stone fruit    Men  88.95  Fruit
# 15  1994-1998         Stone fruit  Women  89.55  Fruit
# ...

# %%
# Fruit types over time (Men) — FAH mean shares

# %% [markdown]
# *Caption:* Fruit at-home shares for Men across four periods. From 1994-1998 to 2007-2008, the largest increase in **Tropical fruit** (+10.67 pp), while the largest decrease in **Other citrus fruit** (-9.61 pp). Shares are in percentage points.

# %%
# Fruit types over time (Women) — FAH mean shares

# %% [markdown]
# *Caption:* Fruit at-home shares for Women across four periods. From 1994-1998 to 2007-2008, the largest increase in **Berries** (+8.79 pp), while the largest decrease in **Melons** (-14.51 pp). Shares are in percentage points.

# %%
# Dairy products over time (Men) — FAH mean shares

# %% [markdown]
# *Caption:* Dairy at-home shares for Men across four periods. From 1994-1998 to 2007-2008, the largest increase in **Butter** (+10.07 pp), while the largest decrease in **Cheese** (-2.95 pp). Shares are in percentage points.

# %%
# Dairy products over time (Women) — FAH mean shares

# %% [markdown]
# *Caption:* Dairy at-home shares for Women across four periods. From 1994-1998 to 2007-2008, the largest increase in **Butter** (+12.36 pp), while the largest decrease in **Cheese** (-12.77 pp). Shares are in percentage points.
